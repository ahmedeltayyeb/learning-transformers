# %%
import torch.nn as nn


q_proj = nn.Linear(4, 8, bias = False)
k_proj = nn.Linear(4, 8, bias = False)
v_proj = nn.Linear(4, 8, bias = False)

# %%
q_proj.weight.shape
# Out:
# torch.Size([8, 4])

# %%
import torch
from self_attention import SelfAttention

# %%
# test
x = torch.randn(6, 16)  # seq_len=6, d_model=16
attn = SelfAttention(d_model=16, d_k=8)
output = attn(x)
print(output.shape)  # what do you expect this to print?
# Out:
# torch.Size([6, 16])
